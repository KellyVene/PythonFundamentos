# %% [markdown]
# <font face="Arial, Helvetica, sans-serif" color='blue' size=3>O Twitter é uma das redes sociais mais vibrantes da atualidade. Com apenas 140 caracteres, podemos nos comunicar de forma mais concisa e direta, compartilhando aquilo que é realmente relevante. E desta imensidão de dados gerada pelo Twitter, muitos insights poderosos podem ser obtidos em tempo real, ajudando empresas e pessoas a compreenderem melhor o mercado em que estão inseridos e com isso tomar melhores decisões. <br /><br />
#
# No capítulo 6 do nosso curso de <a href="http://www.datascienceacademy.com.br/public-course/?courseid=python-fundamentos">Python Fundamentos para Análise de Dados</a>, ensinamos os alunos a coletar dados do Twitter, armazenar no MongoDB (banco de dados NoSQL, ideal para dados não estruturados) e analisar dados usando Pandas e Scikit-learn, duas das ferramentas mais utilizadas pelos Cientistas de Dados que utilizam Python. Abaixo um exemplo do é ensinado no curso. Com poucas linhas de código, você pode ter acesso a insights preciosos.<br /><br />
#
# Se ainda não se inscreveu no curso, não perca tempo. É gratuito. Além deste notebook, você ainda tem acesso aos vídeos, e-books, exercícios e quizzes. <br /><br />
#
# E claro, não deixe de seguir a Data Science Academy no Twitter: <a href="https://twitter.com/dsacademybr">@dsacademybr</a><br /><br />
#
# Bons estudos!<br /><br />
#
# Tiago</font>

# %% [markdown]
# # <font color='blue'>Data Science Academy </font>
# # <font color='blue'>Python Fundamentos Para Análise de Dados</font>
# # <font color='blue'>Capítulo 6</font>

# %% [raw]
# <code><script>
# var myUrl = 'http://datascienceacademy.com.br/blog/2016/stream-de-dados-do-twitter-com-mongodb-pandas-e-scikit-learn';
#
# if(window.top.location.href !== myUrl) {
#     window.top.location.href = myUrl;
# }
# </script></code>

# %% [markdown]
# ### Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no E-book como criar sua API no Twitter

# %%
# Adicione aqui sua Consumer Key
consumer_key = "xxxxxxxxxx"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret = "xxxxxxxxxx"

# %%
# Adicione aqui seu Access Token
access_token = "xxxxxxxxxxx"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "xxxxxxxxxxxx"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para filtrar os Tweets
keywords = ['Big Data', 'Data Mining', 'Data Science', 'Analytics', 'Data Scientist']

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'_id': ObjectId('5744e0bf90849980ee5f0a99'), 'text': '#Sustainability https://t.co/0NLWv9A0ho The much more comprehensive and accurate satellite data shows us that the last time there was any ‘…', 'id_str': '735248071483854848', 'created_at': 'Tue May 24 23:16:15 +0000 2016'}
# {'_id': ObjectId('5744e0c090849980ee5f0a9a'), 'text': 'A Look at the State of the Art in Business Development Software and Analytics - ABA Law Pra… https://t.co/mbL9cG2auS https://t.co/4sYTQVLYQc', 'id_str': '735248073190985728', 'created_at': 'Tue May 24 23:16:15 +0000 2016'}
# {'_id': ObjectId('5744e0c590849980ee5f0a9b'), 'text': 'RT @analyticbridge: 12 Emerging Trends in Data Analytics https://t.co/0bQwGftwLU', 'id_str': '735248097526218752', 'created_at': 'Tue May 24 23:16:21 +0000 2016'}
# ...

# %%
# Encerrando o stream de dados do Twitter
mystream.disconnect()

# %%
# Verificando se existe um documento no collection do MongoDB
col.find_one()
# Out:
# {'_id': ObjectId('5744e0bf90849980ee5f0a99'),
#  'created_at': 'Tue May 24 23:16:15 +0000 2016',
#  'id_str': '735248071483854848',
#  'text': '#Sustainability https://t.co/0NLWv9A0ho The much more comprehensive and accurate satellite data shows us that the last time there was any ‘…'}

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"],
            "text": item["text"],
           } for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Tue May 24 23:16:15 +0000 2016
# 1   Tue May 24 23:16:15 +0000 2016
# 2   Tue May 24 23:16:21 +0000 2016
# 3   Tue May 24 23:16:22 +0000 2016
# 4   Tue May 24 23:16:22 +0000 2016
# 5   Tue May 24 23:16:23 +0000 2016
# 6   Tue May 24 23:16:23 +0000 2016
# 7   Tue May 24 23:16:24 +0000 2016
# 8   Tue May 24 23:16:25 +0000 2016
# 9   Tue May 24 23:16:26 +0000 2016
# 10  Tue May 24 23:16:27 +0000 2016
# 11  Tue May 24 23:16:27 +0000 2016
# 12  Tue May 24 23:16:28 +0000 2016
# 13  Tue May 24 23:16:30 +0000 2016
# 14  Tue May 24 23:16:30 +0000 2016
# 15  Tue May 24 23:16:32 +0000 2016
# 16  Tue May 24 23:16:34 +0000 2016
# 17  Tue May 24 23:16:38 +0000 2016
# 18  Tue May 24 23:16:40 +0000 2016
# 19  Tue May 24 23:16:41 +0000 2016
# 20  Tue May 24 23:16:45 +0000 2016
# 21  Tue May 24 23:16:46 +0000 2016
# 22  Tue May 24 23:16:46 +0000 2016
# 23  Tue May 24 23:16:47 +0000 2016
# 24  Tue May 24 23:16:48 +0000 2016
# ...

# %%
# Importando o módulo Scikit-Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#           word  count
# 0        https     59
# 1           co     56
# 2    analytics     40
# 3          the     36
# 4           rt     24
# 5         data     24
# 6           to     17
# 7          and     16
# 8          for     14
# 9         have     13
# 10        will     12
# 11          of     12
# 12         big     12
# 13          in     10
# 14          by     10
# 15          is     10
# 16         how      9
# 17          at      9
# 18     bigdata      8
# 19         you      8
# 20      google      7
# 21         are      7
# 22        this      7
# 23    families      6
# 24         hit      6
# 25     bartolo      6
# 26         end      6
# 27      season      6
# 28    ithrow88      6
# 29        runs      6
# 30        rate      6
# 31        home      6
# 32          if      5
# 33  predictive      5
# 34     science      5
# 35      social      5
# 36          it      4
# 37   sumologic      4
# 38         iot      4
# 39        with      4
# ...

# %% [markdown]
# ### Nos capítulos 7 e 8 criaremos mais projetos de Data Science usando NumPy, Pandas, Matplotlib, Scitkit-Learn e Stats Models. Até lá!

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href=http://facebook.com/dsacademy>facebook.com/dsacademybr</a>
